# %%
# !pip install transformers==4.41.0
# Out:
# Requirement already satisfied: transformers==4.41.0 in /usr/local/lib/python3.12/dist-packages (4.41.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (3.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (2.32.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.41.0) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.41.0) (2026.2.25)

# %%
from transformers import pipeline
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
summarizer = pipeline("summarization", model="sshleifer/distilbart-cnn-12-6")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]

# %%
user_text = input("Enter your text: ")

if len(user_text.split()) < 50:
    print("Please enter a longer text (at least 50 words)")
else:
    result = summarizer(user_text, max_length=150, min_length=50)
    print("\nSummary:")
    print(result[0]['summary_text'])
# Out:
# Enter your text: Text summarization is essential in today’s information-rich digital world, where massive amounts of data are generated daily from diverse sources. It helps condense large texts into shorter versions while preserving key ideas and meaning. There are two main approaches: extractive summarization, which selects important sentences directly from the text, and abstractive summarization, which generates new sentences based on understanding the content. Each approach has its challenges, including maintaining coherence, readability, and accuracy. Evaluating summaries is also complex, as common metrics may not fully reflect human judgment. Recent advancements in artificial intelligence, especially transformer-based models, have significantly improved summarization quality. However, issues such as bias, misinformation, and ethical concerns still remain important. Overall, summarization systems play a crucial role in improving productivity, decision-making, and accessibility of information across various domains.
#
# Summary:
#  Text summarization is essential in today’s information-rich digital world . It helps condense large texts into shorter versions while preserving key ideas and meaning . Recent advancements in artificial intelligence have significantly improved summarization quality . Issues such as bias, misinformation, and ethical concerns still remain important .
